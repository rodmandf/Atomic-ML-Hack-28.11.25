# %%
import os
import shutil

USER = "rodmandf"
TOKEN = "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"
REPO_NAME = "Atomic-ML-Hack-28.11.25"
EMAIL = "fedrodmand948@gmail.com"

SOURCE_PATH = "/content/drive/MyDrive/Colab Notebooks/Hack_28-11-2025"

WORK_DIR = "/content/clean_upload"


print(f"1. Копируем проект из {SOURCE_PATH} в {WORK_DIR}...")
if os.path.exists(WORK_DIR):
    shutil.rmtree(WORK_DIR)

# Копируем всё, игнорируя старый гит и мусор
def ignore_func(dir, files):
    return [f for f in files if f == '.git' or f == '__pycache__' or f.endswith('.gdoc')]

shutil.copytree(SOURCE_PATH, WORK_DIR, ignore=ignore_func)
print("Копирование завершено.")

# Переходим в чистую папку
os.chdir(WORK_DIR)

print("2. Инициализируем новый Git.")
# !git init
# !git config --global user.email "{EMAIL}"
# !git config --global user.name "{USER}"
# !git branch -M main

gitignore_content = """
*.csv
*.bin
*.safetensors
*.pt
*.pth
__pycache__/
.ipynb_checkpoints/
models/*
# !models/**/
# !models/**/.gitkeep
"""
with open(".gitignore", "w") as f:
    f.write(gitignore_content)

for folder in ["models/base", "models/cointegrated", "models/cointegrated_ART"]:
    os.makedirs(folder, exist_ok=True)
    with open(f"{folder}/.gitkeep", "w") as f:
        f.write("")

print("3. Добавляем файлы.")
# !git add .
# !git status

print("4. Коммит и Пуш.")
# !git commit -m "Clean upload from Colab via copy"

git_url = f"https://{USER}:{TOKEN}@github.com/{USER}/{REPO_NAME}.git"
# !git remote add origin {git_url}
# !git push -u origin main --force

print("\nГОТОВО!")
# Out:
# 1. Копируем проект из /content/drive/MyDrive/Colab Notebooks/Hack_28-11-2025 в /content/clean_upload...
